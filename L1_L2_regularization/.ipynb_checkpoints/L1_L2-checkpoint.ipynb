# %%
import pandas as pd

# %%
df = pd.read_csv('melb_data.csv')

# %%
df.head(20)
# Out:
#         Suburb              Address  Rooms Type      Price Method  SellerG  \
# 0   Abbotsford         85 Turner St      2    h  1480000.0      S   Biggin
# 1   Abbotsford      25 Bloomburg St      2    h  1035000.0      S   Biggin
# 2   Abbotsford         5 Charles St      3    h  1465000.0     SP   Biggin
# 3   Abbotsford     40 Federation La      3    h   850000.0     PI   Biggin
# 4   Abbotsford          55a Park St      4    h  1600000.0     VB   Nelson
# 5   Abbotsford       129 Charles St      2    h   941000.0      S   Jellis
# 6   Abbotsford         124 Yarra St      3    h  1876000.0      S   Nelson
# 7   Abbotsford        98 Charles St      2    h  1636000.0      S   Nelson
# 8   Abbotsford   6/241 Nicholson St      1    u   300000.0      S   Biggin
# 9   Abbotsford        10 Valiant St      2    h  1097000.0      S   Biggin
# 10  Abbotsford   411/8 Grosvenor St      2    u   700000.0     VB   Jellis
# ...

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.shape
# Out:
# (13580, 21)

# %%
df.isna().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df['Car']= df['Car'].fillna(0)

# %%
df.isna().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df['BuildingArea'] = df['BuildingArea'].fillna(df.BuildingArea.mean())

# %%
df['YearBuilt'] = df['YearBuilt'].fillna(df.YearBuilt.mean())

# %%
df.isna().sum()
# Out:
# Rooms                                    0
# Price                                    0
# Distance                                 0
# Bedroom2                                 0
# Bathroom                                 0
#                                         ..
# Regionname_Northern Victoria             0
# Regionname_South-Eastern Metropolitan    0
# Regionname_Southern Metropolitan         0
# Regionname_Western Metropolitan          0
# Regionname_Western Victoria              0
# Length: 13747, dtype: int64

# %%
df = df.drop(['SellerG', 'Date'], axis=1)

# %%
df=df.drop('Postcode',axis=1)

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method  Distance  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S       2.5
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S       2.5
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP       2.5
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI       2.5
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB       2.5
#
#    Bedroom2  Bathroom  Car  Landsize  BuildingArea  YearBuilt CouncilArea  \
# 0       2.0       1.0  1.0     202.0     151.96765        NaN       Yarra
# 1       2.0       1.0  0.0     156.0      79.00000     1900.0       Yarra
# 2       3.0       2.0  0.0     134.0     150.00000     1900.0       Yarra
# 3       3.0       2.0  1.0      94.0     151.96765        NaN       Yarra
# 4       3.0       1.0  2.0     120.0     142.00000     2014.0       Yarra
#
#    Lattitude  Longtitude             Regionname  Propertycount
# ...

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'Distance',
#        'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt',
#        'CouncilArea', 'Lattitude', 'Longtitude', 'Regionname',
#        'Propertycount'],
#       dtype='object')

# %%
df= pd.get_dummies(df,drop_first=True,dtype=int)
df= df.astype(int)
df.head()
# Out:
#    Rooms    Price  Distance  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 0      2  1480000         2         2         1    1       202           151
# 1      2  1035000         2         2         1    0       156            79
# 2      3  1465000         2         3         2    0       134           150
# 3      3   850000         2         3         2    1        94           151
# 4      4  1600000         2         3         1    2       120           142
#
#    YearBuilt  Lattitude  ...  CouncilArea_Wyndham  CouncilArea_Yarra  \
# 0       1964        -37  ...                    0                  1
# 1       1900        -37  ...                    0                  1
# 2       1900        -37  ...                    0                  1
# 3       1964        -37  ...                    0                  1
# 4       2014        -37  ...                    0                  1
#
#    CouncilArea_Yarra Ranges  Regionname_Eastern Victoria  \
# ...

# %%
df.shape
# Out:
# (13580, 13747)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
X=df.drop('Price',axis=1)

# %%
X.shape
# Out:
# (13580, 13746)

# %%
y = df['Price']

# %%
y.shape
# Out:
# (13580,)

# %%
X_train ,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train.shape
# Out:
# (10864, 13746)

# %%
len(X_test)
# Out:
# 2716

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# -57283463.28589649

# %%
model.score(X_train,y_train)
# Out:
# 0.9999309799763287

# %% [markdown]
# #Our model goes into Overfitting

# %% [markdown]
# # our model goes into Overfitting

# %%
from sklearn import linear_model

# %%
l1 = linear_model.Lasso(alpha=2,max_iter=800,tol=1,positive=True)
l1.fit(X_train,y_train)
# Out:
# Lasso(alpha=2, max_iter=800, positive=True, tol=1)

# %%
l1.score(X_test,y_test)
# Out:
# 0.23572774635897353

# %%
from sklearn.model_selection import GridSearchC
param_grid = {
    'alpha': [0.001, 0.01, 0.1, 1, 10, 100],
    'max_iter': [1000, 2000, 5000],
    'tol': [1e-4, 1e-3, 1e-2],
    'fit_intercept': [True, False]
}

# %%
gs = GridSearchCV(l1,param_grid,cv=10)

# %%
l2 = linear_model.Ridge(alpha=2,max_iter=1000,tol=0.08,solver=')
l2.fit(X_train,y_train)
# Out:
# Ridge(alpha=2, max_iter=1000, tol=0.08)

# %%
l2.score(X_test,y_test)
# Out:
# 0.4301606874748405
